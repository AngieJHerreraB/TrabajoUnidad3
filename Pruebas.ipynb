# %% [markdown]
# https://github.com/AngieJHerreraB/TrabajoUnidad3.git

# %%
# !pip install pydicom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.4 MB/s eta 0:00:00
# ...

# %%
# !pip install nilearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 38.6 MB/s eta 0:00:00
# ...

# %%
# !pip install dicom2nifti
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 630.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 44.4 MB/s eta 0:00:00
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.io import loadmat
import scipy.io as ios
import seaborn as sns
import pydicom
from pydicom.data import get_testdata_file
from pydicom import dcmread
import dicom2nifti
import nilearn
import nibabel as nib
from nilearn import plotting, image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Pruebas

# %% [markdown]
# prueba convertir a nifti

# %%
DirectorioDicom = Estudio(r'/content/drive/MyDrive/archivos/0001/IMG0001.dcm')
leer = DirectorioDicom.cargarImagen()
# Out:
# ¡Cargado con éxito!

# %%
# Ruta del directorio que contiene los archivos DICOM
DirectorioDicom = r"/content/drive/MyDrive/archivos/0001"
DirectorioDicom2 = r"/content/drive/MyDrive/archivos/0002"
DirectorioDicom3 = r"/content/drive/MyDrive/archivos/0003"
# Ruta donde se guardarán los archivos NIfTI
DirectorioNifti = r"/content/Nifti"
DirectorioNifti2 = r"/content/Nifti2"
DirectorioNifti3 = r"/content/Nifti3"
# Función para la conversión de formato
dicom2nifti.convert_directory(DirectorioDicom,DirectorioNifti)
dicom2nifti.convert_directory(DirectorioDicom2,DirectorioNifti2)
dicom2nifti.convert_directory(DirectorioDicom3,DirectorioNifti3)
# Out:
# /usr/local/lib/python3.10/dist-packages/dicom2nifti/convert_generic.py:43: RuntimeWarning: invalid value encountered in divide
#   current_direction = current_direction / numpy.linalg.norm(current_direction)
# WARNING:dicom2nifti.convert_generic:Missing slices (slice count mismatch between timepoint 8 and 9)
# WARNING:dicom2nifti.convert_generic:---------------------------------------------------------
# WARNING:dicom2nifti.convert_generic:(205, 235, 2)
# WARNING:dicom2nifti.convert_generic:(205, 235, 3)
# WARNING:dicom2nifti.convert_generic:---------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/dicom2nifti/convert_dir.py", line 85, in convert_directory
#     convert_dicom.dicom_array_to_nifti(dicom_input, nifti_file, reorient)
#   File "/usr/local/lib/python3.10/dist-packages/dicom2nifti/convert_dicom.py", line 124, in dicom_array_to_nifti
# ...

# %%
dcm_data = pydicom.dcmread(r'/content/drive/MyDrive/archivos/0001/IMG0001.dcm')
dcm_data
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 258
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.2.1125.1.35413466869556812327990599999106158
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.3.0.10.111.124.113
# (0002, 0013) Implementation Version Name         SH: 'GDCM 3.0.10'
# (0002, 0016) Source Application Entity Title     AE: 'GDCM/ITK 5.3.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'MPR']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# ...

# %% [markdown]
# Fecha, modalidad, Descripción, dimensiones de la imagen

# %%
dcm_data[0x0008, 0x0020]
# Out:
# (0008, 0020) Study Date                          DA: '20230802'

# %%
dcm_data[0x0008, 0x0060]
# Out:
# (0008, 0060) Modality                            CS: 'MR'

# %%
img=r"/content/Nifti/1_rm_cerebro_t1.nii.gz"
img1=nilearn.image.load_img(img)

#img2=r"/content/Nifti2"
#img22=nilearn.image.load_img(img2)

img3=r"/content/Nifti3/301_ct_heart.nii.gz"
img33=nilearn.image.load_img(img3)

# %%
plotting.plot_anat(img1, title='Corte axial, sagital y coronal',cut_coords=[-40,20,-120])
# Out:
# /usr/local/lib/python3.10/dist-packages/nilearn/image/resampling.py:809: UserWarning: Casting data from int32 to float32
#   return resample_img(

# %%
plotting.plot_anat(img3, title='Corte axial, sagital y coronal',cut_coords=[1,-62,1])

# %%
plotting.plot_anat(img1,
                title='Cerebro',display_mode="mosaic")
# Out:
# /usr/local/lib/python3.10/dist-packages/nilearn/image/resampling.py:809: UserWarning: Casting data from int32 to float32
#   return resample_img(

# %%
plotting.plot_anat(img3,
                title='Corazón',display_mode="mosaic")

# %% [markdown]
# # Anonimizado

# %%
data_elements = ["PatientID","PatientName","StudyID"]
for i in data_elements:
    print(dcm_data.data_element(i))

dcm_data['PatientID'].value
dcm_data['PatientID'].value='anonimo'

dcm_data['PatientName'].value
dcm_data['PatientName'].value='anonimo'

dcm_data['StudyID'].value
dcm_data['StudyID'].value='anonimo'
# Out:
# (0010, 0020) Patient ID                          LO: 'anonimo'
# (0010, 0010) Patient's Name                      PN: 'anonimo'
# (0020, 0010) Study ID                            SH: '7255692790'

# %%
dcm_data['PatientID'].value
# Out:
# 'anonimo'

# %%
dcm_data['PatientName'].value
# Out:
# 'anonimo'

# %%
dcm_data['StudyID'].value
